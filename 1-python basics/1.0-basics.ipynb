# %%
print(1+1)
# Out:
# 2

# %%
name="Shreyas"
Name="Burji"

print(name)
print(Name)
# Out:
# Shreyas
# Burji

# %%
## indentation

age=24
if age>18:
  print(age)
print(age)
# Out:
# 24
# 24

# %%
## line continuation

total=1+2+3+4+5+6+7+\
4+5+6

print(total)
# Out:
# 43

# %%
## multiple statements in a signal line

x=15;y=15;z=x+y
print(z)
# Out:
# 30

# %%
Name="Shreyas Burji"
age=22

# %%
type(age)
# Out:
# int

# %%
type(Name)
# Out:
# str

# %%
Age=22
print(type(Age))
# Out:
# <class 'int'>

# %%
age=22
if age<18:
  print("its is true")
print("it is not true")
# Out:
# it is not true
