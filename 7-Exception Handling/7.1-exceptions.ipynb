# %% [markdown]
# ## understanding Exceptions
# Exception handling in Python allows you to handle errors gracefully and take corrective actions without stopping the exection
# of the program.This lesson will cover the basics of execptions,including how to use try,except, else, and finally blocks.

# %% [markdown]
# ## What is Exceptions?
#
# Exceptions are events that disrupt the normal flow of a program. They occur when an error is encountered during
# program execution. Common execptions includs:
#
#   i. ZeroDivisionError: Dividing by zero.
#   ii. FileNotFoundError: File not Found.
#   iii. ValueError: Invalid value.
#   iv. TypeError: Invalid type.

# %%
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 a=b
#
# NameError: name 'b' is not defined

# %%
## to handle it we use 
# expection try, except block
try:
  a=b
except:
  print("The vaeiable has not been assigned")
# Out:
# The vaeiable has not been assigned

# %%
try:
  a=b
except NameError as ex:
  print(ex)
# Out:
# name 'b' is not defined

# %%
result=1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 result=1/0
#
# ZeroDivisionError: division by zero

# %%
## to handle it we use 
try:
  result=1/0
except ZeroDivisionError as ex:
  print(ex)
# Out:
# division by zero

# %%
try:
  result=1/2
  a=b
except ZeroDivisionError as ex:
  print(ex)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       1 try:
#       2   result=1/2
#       3   a=b
# ----> 4 except ZeroDivisionError as ex:
#       5   print(ex)
#
# NameError: name 'b' is not defined

# %%
## to handle it
try:
  result=1/2
  a=b
except ZeroDivisionError as ex:
  print(ex)
except Exception as ex1:   ## exception handles all types and give result
  print(ex1)
# Out:
# name 'b' is not defined

# %%
try:
  num=int(input("Enter the number"))
  result=10/num
except ValueError:
  print("This is not a valid number")
except ZeroDivisionError:
  print("enter denomitor greater than 0")
except Exception as ex:
  print(ex)
# Out:
# enter denomitor greater than 0

# %%
try:
  num=int(input("Enter the number"))
  result=10/num
except ValueError:
  print("This is not a valid number")
except ZeroDivisionError:
  print("enter denomitor greater than 0")
except Exception as ex:
  print(ex)
# Out:
# This is not a valid number

# %%
## try, execpt, else block
try:
  num=int(input("Enter the number"))
  result=10/num
except ValueError:
  print("This is not a valid number")
except ZeroDivisionError:
  print("enter denomitor greater than 0")
except Exception as ex:
  print(ex)
else:
  print(f"the result is {result}")
# Out:
# the result is 0.18181818181818182

# %%
try:
  num=int(input("Enter the number"))
  result=10/num
except ValueError:
  print("This is not a valid number")
except ZeroDivisionError:
  print("enter denomitor greater than 0")
except Exception as ex:
  print(ex)
else:
  print(f"the result is {result}")
# Out:
# This is not a valid number

# %%
### try, except, else and finally
try:
  num=int(input("Enter the number"))
  result=10/num
except ValueError:
  print("This is not a valid number")
except ZeroDivisionError:
  print("enter denomitor greater than 0")
except Exception as ex:
  print(ex)
else:
  print(f"the result is {result}")
finally:
  print("Exception complete")
# Out:
# the result is 0.29411764705882354
# Exception complete

# %%
try:
  num=int(input("Enter the number"))
  result=10/num
except Exception as ex:
  print(ex)
else:
  print(f"the result is {result}")
finally:
  print("Exception complete")
# Out:
# division by zero
# Exception complete

# %%
## File handling and Exception handling

try:
  file=open('example1.txt','r')
  content=file.read
  print(content)
except FileNotFoundError:
  print("The file does not exists")
finally:
  if 'file' in locals() or not file.closed():
    file.close()
    print('file close')
# Out:
# <built-in method read of _io.TextIOWrapper object at 0x000002610B065380>
# file close
